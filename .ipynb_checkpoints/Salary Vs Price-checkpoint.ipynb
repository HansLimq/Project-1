# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
excel_file = Path("Houses-by-suburb-2013-2023.xlsx")
df_Melb = pd.read_excel(excel_file)

# %%
df_Melb
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      Locality       2013       2014       2015       2016       2017
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3    ABBOTSFORD     792500     862500     925000    1187500    1280000
# 4    ABERFELDIE     947500    1045000    1207500    1300000    1471000
# ..          ...        ...        ...        ...        ...        ...
# 785      YARRAM     190000     202500     245000     230000     225000
# 786  YARRAVILLE     696000     710000     810000     900500    1000000
# 787  YARRAWONGA     302500     297000     300500     320000     324500
# 788         YEA     260000     255000     260000     305000     385000
# 789      YINNAR     220000     240000     182500     230000     270000
#
#     Unnamed: 6 Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# ...

# %%
new_header = df_Melb .iloc[0]

# %%
df_Melb= df_Melb[1:]

# %%
df_Melb.columns = new_header

# %%
df_Melb
# Out:
# 0      Locality    2013     2014     2015     2016     2017     2018     2019  \
# 1           NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2           NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3    ABBOTSFORD  792500   862500   925000  1187500  1280000  1192500  1050000
# 4    ABERFELDIE  947500  1045000  1207500  1300000  1471000  1498500  1390000
# 5       AINTREE       -        -   600000   600000   571000   557500   575000
# ..          ...     ...      ...      ...      ...      ...      ...      ...
# 785      YARRAM  190000   202500   245000   230000   225000   218000   240000
# 786  YARRAVILLE  696000   710000   810000   900500  1000000  1045000   971000
# 787  YARRAWONGA  302500   297000   300500   320000   324500   345000   375000
# 788         YEA  260000   255000   260000   305000   385000   390000   435500
# 789      YINNAR  220000   240000   182500   230000   270000   245000   255000
#
# ...

# %%
#df_Melbourne=pd.DataFrame(df_Melb)

# %%
df_Melb.columns
# Out:
# Index([    'Locality',           2013,           2014,           2015,
#                  2016,           2017,           2018,           2019,
#                2020.0,         2021.0,         2022.0,         2023.0,
#        'Prelim      ',     '   22-23',        '13-23',           'PA'],
#       dtype='object', name=0)

# %%
df_melb_p=df_Melb.rename(columns={2020.0: 2020,  2021.0: 2021, 2022.0: 2022,2023.0:2023 })

# %%
df_Melb_reduced = df_melb_p.dropna(how='any',axis=0)
df_Melb_reduced.reset_index(drop=True, inplace=True)

# %%
df_Melb_reduced
# Out:
# 0        Locality    2013     2014     2015     2016     2017     2018  \
# 0      ABBOTSFORD  792500   862500   925000  1187500  1280000  1192500
# 1      ABERFELDIE  947500  1045000  1207500  1300000  1471000  1498500
# 2    AIREYS INLET  664000   625500   680000   715000   737500   869000
# 3    AIRPORT WEST  532000   575000   635000   742000   845000   845000
# 4       ALBANVALE  313000   328000   345000   439000   526500   546000
# ..            ...     ...      ...      ...      ...      ...      ...
# 686      YARRAGON  258000   297000   284000   300000   280000   390000
# 687        YARRAM  190000   202500   245000   230000   225000   218000
# 688    YARRAVILLE  696000   710000   810000   900500  1000000  1045000
# 689    YARRAWONGA  302500   297000   300500   320000   324500   345000
# 690           YEA  260000   255000   260000   305000   385000   390000
#
# 0       2019       2020       2021       2022       2023 Prelim        \
# ...

# %%
df_Melb_reduced.count()
# Out:
# 0
# Locality        691
# 2013            691
# 2014            691
# 2015            691
# 2016            691
# 2017            691
# 2018            691
# 2019            691
# 2020            691
# 2021            691
# 2022            691
# 2023            691
# Prelim          691
#    22-23        691
# 13-23           691
# PA              691
# dtype: int64

# %%
#Melb_Price_df = df_Melbourne[["Locality", "2013", "2014", "2015", "2016", "2017", "2018","2019","2020.0", "2021.0", "2022.0,"2023.0"]]

# %%
df_Melb_price = df_Melb_reduced.drop(['Prelim      ','   22-23','13-23','PA'],axis=1)

# %%
df_Melb_price
# Out:
# 0        Locality    2013     2014     2015     2016     2017     2018  \
# 0      ABBOTSFORD  792500   862500   925000  1187500  1280000  1192500
# 1      ABERFELDIE  947500  1045000  1207500  1300000  1471000  1498500
# 2    AIREYS INLET  664000   625500   680000   715000   737500   869000
# 3    AIRPORT WEST  532000   575000   635000   742000   845000   845000
# 4       ALBANVALE  313000   328000   345000   439000   526500   546000
# ..            ...     ...      ...      ...      ...      ...      ...
# 686      YARRAGON  258000   297000   284000   300000   280000   390000
# 687        YARRAM  190000   202500   245000   230000   225000   218000
# 688    YARRAVILLE  696000   710000   810000   900500  1000000  1045000
# 689    YARRAWONGA  302500   297000   300500   320000   324500   345000
# 690           YEA  260000   255000   260000   305000   385000   390000
#
# 0       2019       2020       2021       2022       2023
# 0    1050000  1200000.0  1365000.0  1346000.0  1250000.0
# ...

# %%
df_Melb_price.set_index('Locality')
mean_2013 = round(df_Melb_price[2013].astype("float").mean(), 2)
mean_2014=round(df_Melb_price[2014].astype("float").mean(), 2)
mean_2015=round(df_Melb_price[2015].astype("float").mean(), 2)
mean_2016=round(df_Melb_price[2016].astype("float").mean(), 2)
mean_2017=round(df_Melb_price[2017].astype("float").mean(), 2)
mean_2018=round(df_Melb_price[2018].astype("float").mean(), 2)
mean_2019=round(df_Melb_price[2019].astype("float").mean(), 2)
mean_2020=round(df_Melb_price[2020].astype("float").mean(), 2)
mean_2021=round(df_Melb_price[2021].astype("float").mean(), 2)
mean_2022=round(df_Melb_price[2022].astype("float").mean(), 2)
mean_2023=round(df_Melb_price[2023].astype("float").mean(), 2)

# %%
Melb_price_summary = pd.DataFrame({
    2013: [mean_2013],
    2014: [mean_2014],
    2015: [mean_2015],
    2016: [mean_2016],
    2017: [mean_2017],
    2018: [mean_2018],
    2019: [mean_2019],
    2020: [mean_2020],
    2021: [mean_2021],
    2022: [mean_2022],
    2023: [mean_2023],
    })
Melb_price_summary
Melb_housing_price = pd.DataFrame(Melb_price_summary).T
Melb_housing_price.reset_index(inplace=True)
Melb_housing_price.columns = ['Year', 'Price']
Melb_housing_price
# Out:
#     Year      Price
# 0   2013  470395.08
# 1   2014  504963.10
# 2   2015  562489.15
# 3   2016  615270.62
# 4   2017  695069.46
# 5   2018  707043.42
# 6   2019  695089.00
# 7   2020  749727.21
# 8   2021  892358.18
# 9   2022  939518.09
# 10  2023  912255.43

# %%
df_Melb_price_time_chart=Melb_housing_price.plot(kind="line")
#df_Melb_price_time_chart.set_xlabel("Year")            
#df_Melb_price_time_chart.set_ylabel("Melbourne Hosing Price")
#plt.xticks ([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,2021,2022,2023])
#plt.xticks(list(map(int, Melb_housing_price.index.tolist())))
# Set a title for the chart
plt.title("Melbourne Hosing Price vs. Year")

plt.tight_layout()
plt.show()

# %%
excel_file_2 = Path("6302001.xlsx")
df_salary = pd.read_excel(excel_file_2,header=[0,1], index_col=[0,1],skiprows=[2,3,4,5,6,7,8,9], sheet_name="Data1")

# %%
df_salary
# Out:
# Earnings; Males; Full Time; Adult; Ordinary time earnings ; Earnings; Males; Full Time; Adult; Total earnings ;  \
# $                                                                                                             $
# 2012-05-15 1447.1                                                                                       1538.1
# 2012-11-15 1488.5                                                                                       1576.7
# 2013-05-15 1515.7                                                                                       1603.7
# 2013-11-15 1533.9                                                                                       1621.8
# 2014-05-15 1560.7                                                                                       1650.5
# 2014-11-15 1584.6                                                                                       1675.2
# ...

# %%
df_salary.columns
# Out:
# MultiIndex([(          'Earnings; Males; Full Time; Adult; Total earnings ;', ...),
#             (                            'Earnings; Males; Total earnings ;', ...),
#             ('Earnings; Females; Full Time; Adult; Ordinary time earnings ;', ...),
#             (        'Earnings; Females; Full Time; Adult; Total earnings ;', ...),
#             (                          'Earnings; Females; Total earnings ;', ...),
#             ('Earnings; Persons; Full Time; Adult; Ordinary time earnings ;', ...),
#             (        'Earnings; Persons; Full Time; Adult; Total earnings ;', ...),
#             (                          'Earnings; Persons; Total earnings ;', ...)],
#            names=['Earnings; Males; Full Time; Adult; Ordinary time earnings ;', '$'])

# %%
df_salary_clean=df_salary['Earnings; Persons; Total earnings ;']

# %%
df_salary_clean.index
# Out:
# MultiIndex([('2012-05-15', 1447.1),
#             ('2012-11-15', 1488.5),
#             ('2013-05-15', 1515.7),
#             ('2013-11-15', 1533.9),
#             ('2014-05-15', 1560.7),
#             ('2014-11-15', 1584.6),
#             ('2015-05-15', 1593.2),
#             ('2015-11-15', 1602.9),
#             ('2016-05-15', 1615.0),
#             ('2016-11-15', 1629.5),
#             ('2017-05-15', 1640.7),
#             ('2017-11-15', 1662.2),
#             ('2018-05-15', 1678.0),
#             ('2018-11-15', 1697.9),
#             ('2019-05-15', 1725.3),
#             ('2019-11-15', 1756.7),
#             ('2020-05-15', 1795.2),
#             ('2020-11-15', 1810.8),
#             ('2021-05-15', 1832.6),
#             ('2021-11-15', 1848.9),
#             ('2022-05-15', 1873.4),
#             ('2022-11-15', 1906.2),
#             ('2023-05-15', 1940.4),
#             ('2023-11-15', 1981.3)],
#            )

# %%
df_s=df_salary_clean.reset_index()

# %%
df_s.index
# Out:
# RangeIndex(start=0, stop=24, step=1)

# %%
df_salary_r=df_s.rename(columns={'level_0': 'Year',  'level_1':'Male_income', '$':" Weekly Income" })

# %%
df_salary_r
# Out:
# $        Year  Male_income   Weekly Income
# 0  2012-05-15       1447.1          1054.3
# 1  2012-11-15       1488.5          1081.0
# 2  2013-05-15       1515.7          1103.4
# 3  2013-11-15       1533.9          1114.6
# 4  2014-05-15       1560.7          1122.5
# 5  2014-11-15       1584.6          1129.0
# 6  2015-05-15       1593.2          1136.7
# 7  2015-11-15       1602.9          1146.8
# 8  2016-05-15       1615.0          1158.9
# 9  2016-11-15       1629.5          1165.5
# 10 2017-05-15       1640.7          1178.2
# 11 2017-11-15       1662.2          1191.9
# 12 2018-05-15       1678.0          1207.7
# 13 2018-11-15       1697.9          1224.5
# 14 2019-05-15       1725.3          1239.1
# 15 2019-11-15       1756.7          1255.8
# 16 2020-05-15       1795.2          1268.0
# 17 2020-11-15       1810.8          1281.9
# 18 2021-05-15       1832.6          1305.3
# 19 2021-11-15       1848.9          1327.6
# 20 2022-05-15       1873.4          1347.4
# ...

# %%
df_salary_r.columns
# Out:
# Index(['Year', 'Male_income', ' Weekly Income'], dtype='object', name='$')

# %%
df_salary_ready = df_salary_r.drop(columns=['Male_income'])

# %%
df_salary_ready
# Out:
# $        Year   Weekly Income
# 0  2012-05-15          1054.3
# 1  2012-11-15          1081.0
# 2  2013-05-15          1103.4
# 3  2013-11-15          1114.6
# 4  2014-05-15          1122.5
# 5  2014-11-15          1129.0
# 6  2015-05-15          1136.7
# 7  2015-11-15          1146.8
# 8  2016-05-15          1158.9
# 9  2016-11-15          1165.5
# 10 2017-05-15          1178.2
# 11 2017-11-15          1191.9
# 12 2018-05-15          1207.7
# 13 2018-11-15          1224.5
# 14 2019-05-15          1239.1
# 15 2019-11-15          1255.8
# 16 2020-05-15          1268.0
# 17 2020-11-15          1281.9
# 18 2021-05-15          1305.3
# 19 2021-11-15          1327.6
# 20 2022-05-15          1347.4
# 21 2022-11-15          1376.1
# 22 2023-05-15          1401.4
# 23 2023-11-15          1431.1

# %%
df_salary_ready.dtypes
# Out:
# $
# Year              datetime64[ns]
#  Weekly Income           float64
# dtype: object

# %%
fitlter_salary=df_salary_ready[df_salary_ready['Year'].dt.month==11]

# %%
fitlter_salary['Annual_Salary']= fitlter_salary[' Weekly Income'] * 52
# Out:
# C:\Users\Ariaaa\AppData\Local\Temp\ipykernel_5576\3347563268.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitlter_salary['Annual_Salary']= fitlter_salary[' Weekly Income'] * 52

# %%
fitlter_salary
# Out:
# $        Year   Weekly Income  Annual_Salary
# 1  2012-11-15          1081.0        56212.0
# 3  2013-11-15          1114.6        57959.2
# 5  2014-11-15          1129.0        58708.0
# 7  2015-11-15          1146.8        59633.6
# 9  2016-11-15          1165.5        60606.0
# 11 2017-11-15          1191.9        61978.8
# 13 2018-11-15          1224.5        63674.0
# 15 2019-11-15          1255.8        65301.6
# 17 2020-11-15          1281.9        66658.8
# 19 2021-11-15          1327.6        69035.2
# 21 2022-11-15          1376.1        71557.2
# 23 2023-11-15          1431.1        74417.2

# %%
fitlter_salary['Year'] = fitlter_salary['Year'].dt.year
# Out:
# C:\Users\Ariaaa\AppData\Local\Temp\ipykernel_5576\3393866221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitlter_salary['Year'] = fitlter_salary['Year'].dt.year

# %%
fitlter_salary
# Out:
# $   Year   Weekly Income  Annual_Salary
# 1   2012          1081.0        56212.0
# 3   2013          1114.6        57959.2
# 5   2014          1129.0        58708.0
# 7   2015          1146.8        59633.6
# 9   2016          1165.5        60606.0
# 11  2017          1191.9        61978.8
# 13  2018          1224.5        63674.0
# 15  2019          1255.8        65301.6
# 17  2020          1281.9        66658.8
# 19  2021          1327.6        69035.2
# 21  2022          1376.1        71557.2
# 23  2023          1431.1        74417.2

# %%
annual_salary_df=fitlter_salary.drop(columns=[' Weekly Income'])

# %%
annual_salary=annual_salary_df.drop(1)

# %%
annual_salary.set_index('Year')
# Out:
# $     Annual_Salary
# Year
# 2013        57959.2
# 2014        58708.0
# 2015        59633.6
# 2016        60606.0
# 2017        61978.8
# 2018        63674.0
# 2019        65301.6
# 2020        66658.8
# 2021        69035.2
# 2022        71557.2
# 2023        74417.2

# %%
annual_salary.columns
# Out:
# Index(['Year', 'Annual_Salary'], dtype='object', name='$')

# %%
#linear regession

# %%
Salary_price=pd.merge(annual_salary,Melb_housing_price, on=['Year'],how='inner',suffixes=['_and'])

# %%
Salary_price
# Out:
#     Year  Annual_Salary      Price
# 0   2013        57959.2  470395.08
# 1   2014        58708.0  504963.10
# 2   2015        59633.6  562489.15
# 3   2016        60606.0  615270.62
# 4   2017        61978.8  695069.46
# 5   2018        63674.0  707043.42
# 6   2019        65301.6  695089.00
# 7   2020        66658.8  749727.21
# 8   2021        69035.2  892358.18
# 9   2022        71557.2  939518.09
# 10  2023        74417.2  912255.43

# %%
# Null Hypothesis

* Does the increase of the salary pushes the property house price higher?

  * Alternate hypothesis - When salary is increasing, the house prices will be increasing.

  * Null Hypothesis - The increase of salary show no increase in the housing price.

# %%
salary_vs_price_chart= Salary_price.plot(x="Annual_Salary", y="Price", kind="scatter")
salary_vs_price_chart.set_xlabel("Annual_Salary")
salary_vs_price_chart.set_ylabel("Melbourne Housing Price")

# Set a title for the chart
plt.title("Annual_Salary vs. Melbourne House Price")

plt.tight_layout()
plt.show()

# %%
salary_vs_price_chart= Salary_price.plot(x="Annual_Salary", y="Price", kind="scatter")
p_slope, p_int, p_r, p_p, p_std_err = st.linregress("Annual_Salary","Price")
p_fit = p_slope * Annual_Salary + p_int
plt.plot('Annual_Salary',p_fit,"-")
plt.xticks('Annual_Salary')
plt.xlabel('Auual Salary')
plt.ylabel('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[260], line 2
#       1 salary_vs_price_chart= Salary_price.plot(x="Annual_Salary", y="Price", kind="scatter")
# ----> 2 p_slope, p_int, p_r, p_p, p_std_err = st.linregress("Annual_Salary","Price")
#       3 p_fit = p_slope * Annual_Salary + p_int
#       4 plt.plot('Annual_Salary',p_fit,"-")
#
# File ~\anaconda3\envs\dev\lib\site-packages\scipy\stats\_stats_mstats_common.py:156, in linregress(x, y, alternative)
#     153 if x.size == 0 or y.size == 0:
#     154     raise ValueError("Inputs must not be empty.")
# --> 156 if np.amax(x) == np.amin(x) and len(x) > 1:
#     157     raise ValueError("Cannot calculate a linear regression "
#     158                      "if all x values are identical")
#     160 n = len(x)
#
# ...
