# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
excel_file = Path("Houses-by-suburb-2013-2023.xlsx")
df_Melb = pd.read_excel(excel_file)

# %%
df_Melb
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      Locality       2013       2014       2015       2016       2017
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3    ABBOTSFORD     792500     862500     925000    1187500    1280000
# 4    ABERFELDIE     947500    1045000    1207500    1300000    1471000
# ..          ...        ...        ...        ...        ...        ...
# 785      YARRAM     190000     202500     245000     230000     225000
# 786  YARRAVILLE     696000     710000     810000     900500    1000000
# 787  YARRAWONGA     302500     297000     300500     320000     324500
# 788         YEA     260000     255000     260000     305000     385000
# 789      YINNAR     220000     240000     182500     230000     270000
#
#     Unnamed: 6 Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# ...

# %%
new_header = df_Melb .iloc[0]
df_Melb= df_Melb[1:]
df_Melb.columns = new_header 
df_Melb
# Out:
# 0      Locality    2013     2014     2015     2016     2017     2018     2019  \
# 1           NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2           NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3    ABBOTSFORD  792500   862500   925000  1187500  1280000  1192500  1050000
# 4    ABERFELDIE  947500  1045000  1207500  1300000  1471000  1498500  1390000
# 5       AINTREE       -        -   600000   600000   571000   557500   575000
# ..          ...     ...      ...      ...      ...      ...      ...      ...
# 785      YARRAM  190000   202500   245000   230000   225000   218000   240000
# 786  YARRAVILLE  696000   710000   810000   900500  1000000  1045000   971000
# 787  YARRAWONGA  302500   297000   300500   320000   324500   345000   375000
# 788         YEA  260000   255000   260000   305000   385000   390000   435500
# 789      YINNAR  220000   240000   182500   230000   270000   245000   255000
#
# ...

# %%
#df_Melbourne=pd.DataFrame(df_Melb)
df_Melb.columns
# Out:
# Index([    'Locality',           2013,           2014,           2015,
#                  2016,           2017,           2018,           2019,
#                2020.0,         2021.0,         2022.0,         2023.0,
#        'Prelim      ',     '   22-23',        '13-23',           'PA'],
#       dtype='object', name=0)

# %%
df_melb_p=df_Melb.rename(columns={2020.0: 2020,  2021.0: 2021, 2022.0: 2022,2023.0:2023 })
df_Melb_reduced = df_melb_p.dropna(how='any',axis=0)
df_Melb_reduced.reset_index(drop=True, inplace=True)
df_Melb_reduced
# Out:
# 0        Locality    2013     2014     2015     2016     2017     2018  \
# 0      ABBOTSFORD  792500   862500   925000  1187500  1280000  1192500
# 1      ABERFELDIE  947500  1045000  1207500  1300000  1471000  1498500
# 2    AIREYS INLET  664000   625500   680000   715000   737500   869000
# 3    AIRPORT WEST  532000   575000   635000   742000   845000   845000
# 4       ALBANVALE  313000   328000   345000   439000   526500   546000
# ..            ...     ...      ...      ...      ...      ...      ...
# 686      YARRAGON  258000   297000   284000   300000   280000   390000
# 687        YARRAM  190000   202500   245000   230000   225000   218000
# 688    YARRAVILLE  696000   710000   810000   900500  1000000  1045000
# 689    YARRAWONGA  302500   297000   300500   320000   324500   345000
# 690           YEA  260000   255000   260000   305000   385000   390000
#
# 0       2019       2020       2021       2022       2023 Prelim        \
# ...

# %%
df_Melb_reduced.count()
# Out:
# 0
# Locality        691
# 2013            691
# 2014            691
# 2015            691
# 2016            691
# 2017            691
# 2018            691
# 2019            691
# 2020            691
# 2021            691
# 2022            691
# 2023            691
# Prelim          691
#    22-23        691
# 13-23           691
# PA              691
# dtype: int64

# %%
#Melb_Price_df = df_Melbourne[["Locality", "2013", "2014", "2015", "2016", "2017", "2018","2019","2020.0", "2021.0", "2022.0,"2023.0"]]
df_Melb_price = df_Melb_reduced.drop(['Prelim      ','   22-23','13-23','PA'],axis=1)
df_Melb_price
# Out:
# 0        Locality    2013     2014     2015     2016     2017     2018  \
# 0      ABBOTSFORD  792500   862500   925000  1187500  1280000  1192500
# 1      ABERFELDIE  947500  1045000  1207500  1300000  1471000  1498500
# 2    AIREYS INLET  664000   625500   680000   715000   737500   869000
# 3    AIRPORT WEST  532000   575000   635000   742000   845000   845000
# 4       ALBANVALE  313000   328000   345000   439000   526500   546000
# ..            ...     ...      ...      ...      ...      ...      ...
# 686      YARRAGON  258000   297000   284000   300000   280000   390000
# 687        YARRAM  190000   202500   245000   230000   225000   218000
# 688    YARRAVILLE  696000   710000   810000   900500  1000000  1045000
# 689    YARRAWONGA  302500   297000   300500   320000   324500   345000
# 690           YEA  260000   255000   260000   305000   385000   390000
#
# 0       2019       2020       2021       2022       2023
# 0    1050000  1200000.0  1365000.0  1346000.0  1250000.0
# ...

# %%
df_Melb_price.set_index('Locality')
mean_2013 = round(df_Melb_price[2013].astype("float").mean(), 2)
mean_2014=round(df_Melb_price[2014].astype("float").mean(), 2)
mean_2015=round(df_Melb_price[2015].astype("float").mean(), 2)
mean_2016=round(df_Melb_price[2016].astype("float").mean(), 2)
mean_2017=round(df_Melb_price[2017].astype("float").mean(), 2)
mean_2018=round(df_Melb_price[2018].astype("float").mean(), 2)
mean_2019=round(df_Melb_price[2019].astype("float").mean(), 2)
mean_2020=round(df_Melb_price[2020].astype("float").mean(), 2)
mean_2021=round(df_Melb_price[2021].astype("float").mean(), 2)
mean_2022=round(df_Melb_price[2022].astype("float").mean(), 2)
mean_2023=round(df_Melb_price[2023].astype("float").mean(), 2)

# %%
Melb_price_summary = pd.DataFrame({
    2013: [mean_2013],
    2014: [mean_2014],
    2015: [mean_2015],
    2016: [mean_2016],
    2017: [mean_2017],
    2018: [mean_2018],
    2019: [mean_2019],
    2020: [mean_2020],
    2021: [mean_2021],
    2022: [mean_2022],
    2023: [mean_2023],
    })
Melb_price_summary
Melb_housing_price = pd.DataFrame(Melb_price_summary).T
Melb_housing_price.reset_index(inplace=True)
Melb_housing_price.columns = ['Year', 'Price']
Melb_housing_price
# Out:
#     Year      Price
# 0   2013  470395.08
# 1   2014  504963.10
# 2   2015  562489.15
# 3   2016  615270.62
# 4   2017  695069.46
# 5   2018  707043.42
# 6   2019  695089.00
# 7   2020  749727.21
# 8   2021  892358.18
# 9   2022  939518.09
# 10  2023  912255.43

# %%
df_Melb_price_time_chart=Melb_housing_price.plot(x="Year", y="Price",kind="line")
#df_Melb_price_time_chart.set_xlabel("Year")            
#df_Melb_price_time_chart.set_ylabel("Melbourne Hosing Price")
plt.xticks ([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,2021,2022,2023])
#plt.xticks(list(map(int, Melb_housing_price.index.tolist())))
# Set a title for the chart
plt.title("Melbourne Hosing Price vs. Year")

plt.tight_layout()
plt.show()

# %%
#Importing the pandas,numpy and matplotlib libaries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#Creating the data from the 310104.xlsx sheet Data1.
data_frame = pd.read_excel('310104.xlsx',sheet_name='Data1')
#displaying first 10 rows to view the data format
data_frame.head(n = 10)
# Out:
#             Unnamed: 0  \
# 0                 Unit
# 1          Series Type
# 2            Data Type
# 3            Frequency
# 4     Collection Month
# 5         Series Start
# 6           Series End
# 7              No. Obs
# 8            Series ID
# 9  1981-06-01 00:00:00
#
#   Estimated Resident Population ;  Male ;  New South Wales ;  \
# 0                                            Persons
# 1                                           Original
# 2                                        STOCK_CLOSE
# 3                                            Quarter
# 4                                                  3
# 5                                1981-06-01 00:00:00
# 6                                2023-12-01 00:00:00
# 7                                                171
# 8                                          A2060825C
# 9                                            2608351
#
#   Estimated Resident Population ;  Male ;  Victoria ;  \
# ...

# %%
#Displaying the name of the columns
data_frame.columns
# Out:
# Index(['Unnamed: 0',
#        'Estimated Resident Population ;  Male ;  New South Wales ;',
#        'Estimated Resident Population ;  Male ;  Victoria ;',
#        'Estimated Resident Population ;  Male ;  Queensland ;',
#        'Estimated Resident Population ;  Male ;  South Australia ;',
#        'Estimated Resident Population ;  Male ;  Western Australia ;',
#        'Estimated Resident Population ;  Male ;  Tasmania ;',
#        'Estimated Resident Population ;  Male ;  Northern Territory ;',
#        'Estimated Resident Population ;  Male ;  Australian Capital Territory ;',
#        'Estimated Resident Population ;  Male ;  Australia ;',
#        'Estimated Resident Population ;  Female ;  New South Wales ;',
#        'Estimated Resident Population ;  Female ;  Victoria ;',
#        'Estimated Resident Population ;  Female ;  Queensland ;',
#        'Estimated Resident Population ;  Female ;  South Australia ;',
# ...

# %%
#Getting the required columns for further analysis.
time_population_vic_df = data_frame.loc[:,['Unnamed: 0','Estimated Resident Population ;  Persons ;  Victoria ;']]
time_population_vic_df.head(10)
# Out:
#             Unnamed: 0 Estimated Resident Population ;  Persons ;  Victoria ;
# 0                 Unit                                            Persons
# 1          Series Type                                           Original
# 2            Data Type                                        STOCK_CLOSE
# 3            Frequency                                            Quarter
# 4     Collection Month                                                  3
# 5         Series Start                                1981-06-01 00:00:00
# 6           Series End                                2023-12-01 00:00:00
# 7              No. Obs                                                171
# 8            Series ID                                          A2060844K
# 9  1981-06-01 00:00:00                                            3946917

# %%
#checking the first 9 rows  and it  shows 9 rows doesn't contain the required data. So cleaning dataframe for data from 9th row till last row.
time_population_vic_df = time_population_vic_df.loc[9:,:]
time_population_vic_df
# Out:
#               Unnamed: 0  \
# 9    1981-06-01 00:00:00
# 10   1981-09-01 00:00:00
# 11   1981-12-01 00:00:00
# 12   1982-03-01 00:00:00
# 13   1982-06-01 00:00:00
# ..                   ...
# 175  2022-12-01 00:00:00
# 176  2023-03-01 00:00:00
# 177  2023-06-01 00:00:00
# 178  2023-09-01 00:00:00
# 179  2023-12-01 00:00:00
#
#     Estimated Resident Population ;  Persons ;  Victoria ;
# 9                                              3946917
# 10                                             3957333
# 11                                             3968398
# 12                                             3980826
# 13                                             3992870
# ..                                                 ...
# 175                                            6719487
# 176                                            6776366
# 177                                            6818442
# 178                                            6869418
# ...

# %%
#Rename the columns.
renaming_columns = {'Unnamed: 0':'Date','Estimated Resident Population ;  Persons ;  Victoria ;':'Estimated Population Victoria'}
time_population_vic_df.rename(columns=renaming_columns,inplace=True)
time_population_vic_df
# Out:
#                     Date Estimated Population Victoria
# 9    1981-06-01 00:00:00                       3946917
# 10   1981-09-01 00:00:00                       3957333
# 11   1981-12-01 00:00:00                       3968398
# 12   1982-03-01 00:00:00                       3980826
# 13   1982-06-01 00:00:00                       3992870
# ..                   ...                           ...
# 175  2022-12-01 00:00:00                       6719487
# 176  2023-03-01 00:00:00                       6776366
# 177  2023-06-01 00:00:00                       6818442
# 178  2023-09-01 00:00:00                       6869418
# 179  2023-12-01 00:00:00                       6905978
#
# [171 rows x 2 columns]

# %%
time_population_vic_df['Date']
# Out:
# 9      1981-06-01 00:00:00
# 10     1981-09-01 00:00:00
# 11     1981-12-01 00:00:00
# 12     1982-03-01 00:00:00
# 13     1982-06-01 00:00:00
#               ...
# 175    2022-12-01 00:00:00
# 176    2023-03-01 00:00:00
# 177    2023-06-01 00:00:00
# 178    2023-09-01 00:00:00
# 179    2023-12-01 00:00:00
# Name: Date, Length: 171, dtype: object

# %%
#change to date
time_population_vic_df['Date'] = pd.to_datetime(time_population_vic_df['Date'],format='%Y-%m-%d')

#change population to integer
time_population_vic_df['Estimated Population Victoria'] = time_population_vic_df['Estimated Population Victoria'].astype(int)
#Filter and get only the population data  from 2013 Dec  to 2023 Dec.
time_population_vic_df
# Out:
#           Date  Estimated Population Victoria
# 9   1981-06-01                        3946917
# 10  1981-09-01                        3957333
# 11  1981-12-01                        3968398
# 12  1982-03-01                        3980826
# 13  1982-06-01                        3992870
# ..         ...                            ...
# 175 2022-12-01                        6719487
# 176 2023-03-01                        6776366
# 177 2023-06-01                        6818442
# 178 2023-09-01                        6869418
# 179 2023-12-01                        6905978
#
# [171 rows x 2 columns]

# %%
#Filter and get only the population data  from 2013 Dec  to 2023 Dec.
time_population_vic_2013_2023_dec = time_population_vic_df[(time_population_vic_df['Date']>= '2013-12-01') & (time_population_vic_df['Date']<= '2023-12-31')]
time_population_vic_2013_2023_dec.to_csv("time_population_vic_2013_2023_dec.csv",index=False)
#Plot graph to check the relation Population VS Years.
plt.title("Australia's Victoria Population from 2013 Dec to 2023 Dec ")
plt.xlabel("Years")
plt.ylabel("Populations (millions)")
plt.plot(time_population_vic_2013_2023_dec['Date'], time_population_vic_2013_2023_dec['Estimated Population Victoria'])
plt.show()

# %%
Melb_housing_price
# Out:
#     Year      Price
# 0   2013  470395.08
# 1   2014  504963.10
# 2   2015  562489.15
# 3   2016  615270.62
# 4   2017  695069.46
# 5   2018  707043.42
# 6   2019  695089.00
# 7   2020  749727.21
# 8   2021  892358.18
# 9   2022  939518.09
# 10  2023  912255.43

# %%
#Getting the mean population for each year from 2013 to 2023.
time_population_vic_2013_2023_dec.groupby(time_population_vic_2013_2023_dec['Date'].dt.year).agg(['mean'])['Estimated Population Victoria']
# Out:
#             mean
# Date
# 2013  5832585.00
# 2014  5912284.75
# 2015  6042033.50
# 2016  6188358.00
# 2017  6318221.75
# 2018  6439073.75
# 2019  6553492.25
# 2020  6597578.50
# 2021  6555549.00
# 2022  6656905.25
# 2023  6842551.00

# %%
# Plotting Population and Housing Price
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot Housing Price
ax1.set_xlabel('Year')
ax1.set_ylabel('House Price', color='tab:blue')
ax1.plot([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,2021,2022,2023],Melb_housing_price['Price'] , color='tab:blue', label='Housing Price')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis to plot Population
ax2 = ax1.twinx()
ax2.set_ylabel('Population', color='tab:red')
ax2.plot(time_population_vic_2013_2023_dec.groupby(time_population_vic_2013_2023_dec['Date'].dt.year).agg(['mean'])['Estimated Population Victoria'], color='tab:red', label='Population')
ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.ticklabel_format(style='plain')
# Adding a title
plt.title('Population and Housing Prices Over Time')

# Show plot with legends
fig.tight_layout()
fig.legend(loc='upper left', bbox_to_anchor=(0.1,0.9))

plt.show()

# %%
import pandas as pd
import scipy.stats as stats
# Assuming the data is already loaded into these DataFrames
Melb_housing_price = pd.DataFrame({
    'Year': [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Price': [470395.08, 504963.10, 562489.15, 615270.62, 695069.46, 707043.42, 695089.00, 749727.21, 892358.18, 939518.09, 912255.43]
})
time_population_vic_df = pd.DataFrame({
    'Year': [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Estimated Population Victoria': [5896190, 5998700, 6102230, 6206910, 6312880, 6419890, 6527960, 6637950, 6748970, 6860980, 6974920]
})
# Print column names to verify
print("Melb_housing_price columns:", Melb_housing_price.columns)
print("time_population_vic_df columns:", time_population_vic_df.columns)
# Calculate the Pearson correlation coefficient
correlation, p_value = stats.pearsonr(Melb_housing_price['Price'], time_population_vic_df['Estimated Population Victoria'])
# Test
print(f"Pearson correlation coefficient: {correlation}")
print(f"P-value: {p_value}")
# Perform t-test
t_stat, p_val = stats.ttest_ind(Melb_housing_price['Price'], time_population_vic_df['Estimated Population Victoria'], equal_var=False)
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# Melb_housing_price columns: Index(['Year', 'Price'], dtype='object')
# time_population_vic_df columns: Index(['Year', 'Estimated Population Victoria'], dtype='object')
# Pearson correlation coefficient: 0.9760828594662141
# P-value: 2.8619818023337094e-07
# T-statistic: -48.39607427886314
# P-value: 6.985087809142011e-17
