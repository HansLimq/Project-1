# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
excel_file = Path("Houses-by-suburb-2013-2023.xlsx")
df_Melb = pd.read_excel(excel_file)

# %%
df_Melb
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      Locality       2013       2014       2015       2016       2017
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3    ABBOTSFORD     792500     862500     925000    1187500    1280000
# 4    ABERFELDIE     947500    1045000    1207500    1300000    1471000
# ..          ...        ...        ...        ...        ...        ...
# 785      YARRAM     190000     202500     245000     230000     225000
# 786  YARRAVILLE     696000     710000     810000     900500    1000000
# 787  YARRAWONGA     302500     297000     300500     320000     324500
# 788         YEA     260000     255000     260000     305000     385000
# 789      YINNAR     220000     240000     182500     230000     270000
#
#     Unnamed: 6 Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0         2018       2019      2020.0      2021.0       2022.0       2023.0
# 1          NaN        NaN         NaN         NaN          NaN          NaN
# 2          NaN        NaN         NaN         NaN          NaN          NaN
# 3      1192500    1050000   1200000.0   1365000.0    1346000.0    1250000.0
# 4      1498500    1390000   1520000.0   1858000.0    1900000.0    1631000.0
# ..         ...        ...         ...         ...          ...          ...
# 785     218000     240000    260000.0    360000.0     470000.0     395000.0
# 786    1045000     971000   1030000.0   1185000.0    1210000.0    1100000.0
# 787     345000     375000    456500.0    564500.0     670000.0     640000.0
# 788     390000     435500    422500.0    570000.0     617500.0     550000.0
# 789     245000     255000    292500.0    465000.0     550500.0     567500.0
#
#            Change Unnamed: 13 Unnamed: 14 Growth
# 0    Prelim             22-23       13-23     PA
# 1            2024         (%)         (%)  13-23
# 2             NaN         NaN         NaN    (%)
# 3         1027500          -7          58    4.7
# 4         3900000         -14          72    5.6
# ..            ...         ...         ...    ...
# 785        425000         -16         108    7.6
# 786       1112500          -9          58    4.7
# 787        637500          -4         112    7.8
# 788        496000         -11         112    7.8
# 789           NaN           3         158    9.9
#
# [790 rows x 16 columns]

# %%
new_header = df_Melb .iloc[0]

# %%
df_Melb= df_Melb[1:]

# %%
df_Melb.columns = new_header

# %%
df_Melb
# Out:
# 0      Locality    2013     2014     2015     2016     2017     2018     2019  \
# 1           NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2           NaN     NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3    ABBOTSFORD  792500   862500   925000  1187500  1280000  1192500  1050000
# 4    ABERFELDIE  947500  1045000  1207500  1300000  1471000  1498500  1390000
# 5       AINTREE       -        -   600000   600000   571000   557500   575000
# ..          ...     ...      ...      ...      ...      ...      ...      ...
# 785      YARRAM  190000   202500   245000   230000   225000   218000   240000
# 786  YARRAVILLE  696000   710000   810000   900500  1000000  1045000   971000
# 787  YARRAWONGA  302500   297000   300500   320000   324500   345000   375000
# 788         YEA  260000   255000   260000   305000   385000   390000   435500
# 789      YINNAR  220000   240000   182500   230000   270000   245000   255000
#
# 0       2020.0     2021.0     2022.0     2023.0 Prelim          22-23 13-23  \
# 1          NaN        NaN        NaN        NaN         2024      (%)   (%)
# 2          NaN        NaN        NaN        NaN          NaN      NaN   NaN
# 3    1200000.0  1365000.0  1346000.0  1250000.0      1027500       -7    58
# 4    1520000.0  1858000.0  1900000.0  1631000.0      3900000      -14    72
# 5     616000.0   713500.0   756000.0   748000.0       753500       -1   NaN
# ..         ...        ...        ...        ...          ...      ...   ...
# 785   260000.0   360000.0   470000.0   395000.0       425000      -16   108
# 786  1030000.0  1185000.0  1210000.0  1100000.0      1112500       -9    58
# 787   456500.0   564500.0   670000.0   640000.0       637500       -4   112
# 788   422500.0   570000.0   617500.0   550000.0       496000      -11   112
# 789   292500.0   465000.0   550500.0   567500.0          NaN        3   158
#
# 0       PA
# 1    13-23
# 2      (%)
# 3      4.7
# 4      5.6
# 5      NaN
# ..     ...
# 785    7.6
# 786    4.7
# 787    7.8
# 788    7.8
# 789    9.9
#
# [789 rows x 16 columns]

# %%
#df_Melbourne=pd.DataFrame(df_Melb)

# %%
df_Melb.columns
# Out:
# Index([    'Locality',           2013,           2014,           2015,
#                  2016,           2017,           2018,           2019,
#                2020.0,         2021.0,         2022.0,         2023.0,
#        'Prelim      ',     '   22-23',        '13-23',           'PA'],
#       dtype='object', name=0)

# %%
df_melb_p=df_Melb.rename(columns={2020.0: 2020,  2021.0: 2021, 2022.0: 2022,2023.0:2023 })

# %%
df_Melb_reduced = df_melb_p.dropna(how='any',axis=0)
df_Melb_reduced.reset_index(drop=True, inplace=True)

# %%
df_Melb_reduced
# Out:
# 0        Locality    2013     2014     2015     2016     2017     2018  \
# 0      ABBOTSFORD  792500   862500   925000  1187500  1280000  1192500
# 1      ABERFELDIE  947500  1045000  1207500  1300000  1471000  1498500
# 2    AIREYS INLET  664000   625500   680000   715000   737500   869000
# 3    AIRPORT WEST  532000   575000   635000   742000   845000   845000
# 4       ALBANVALE  313000   328000   345000   439000   526500   546000
# ..            ...     ...      ...      ...      ...      ...      ...
# 686      YARRAGON  258000   297000   284000   300000   280000   390000
# 687        YARRAM  190000   202500   245000   230000   225000   218000
# 688    YARRAVILLE  696000   710000   810000   900500  1000000  1045000
# 689    YARRAWONGA  302500   297000   300500   320000   324500   345000
# 690           YEA  260000   255000   260000   305000   385000   390000
#
# 0       2019       2020       2021       2022       2023 Prelim        \
# 0    1050000  1200000.0  1365000.0  1346000.0  1250000.0      1027500
# 1    1390000  1520000.0  1858000.0  1900000.0  1631000.0      3900000
# 2     985000  1132500.0  1775000.0  1725000.0  1675000.0      1625000
# 3     795000   812500.0   960000.0   911000.0   945000.0       860000
# 4     512000   545000.0   610000.0   600000.0   595000.0       612000
# ..       ...        ...        ...        ...        ...          ...
# 686   410000   414000.0   582500.0   595000.0   645000.0       613500
# 687   240000   260000.0   360000.0   470000.0   395000.0       425000
# 688   971000  1030000.0  1185000.0  1210000.0  1100000.0      1112500
# 689   375000   456500.0   564500.0   670000.0   640000.0       637500
# 690   435500   422500.0   570000.0   617500.0   550000.0       496000
#
# 0      22-23 13-23   PA
# 0         -7    58  4.7
# 1        -14    72  5.6
# 2         -3   152  9.7
# 3          4    78  5.9
# 4         -1    90  6.6
# ..       ...   ...  ...
# 686        8   150  9.6
# 687      -16   108  7.6
# 688       -9    58  4.7
# 689       -4   112  7.8
# 690      -11   112  7.8
#
# [691 rows x 16 columns]

# %%
df_Melb_reduced.count()
# Out:
# 0
# Locality        691
# 2013            691
# 2014            691
# 2015            691
# 2016            691
# 2017            691
# 2018            691
# 2019            691
# 2020            691
# 2021            691
# 2022            691
# 2023            691
# Prelim          691
#    22-23        691
# 13-23           691
# PA              691
# dtype: int64

# %%
#Melb_Price_df = df_Melbourne[["Locality", "2013", "2014", "2015", "2016", "2017", "2018","2019","2020.0", "2021.0", "2022.0,"2023.0"]]

# %%
df_Melb_price = df_Melb_reduced.drop(['Prelim      ','   22-23','13-23','PA'],axis=1)

# %%
df_Melb_price
# Out:
# 0        Locality    2013     2014     2015     2016     2017     2018  \
# 0      ABBOTSFORD  792500   862500   925000  1187500  1280000  1192500
# 1      ABERFELDIE  947500  1045000  1207500  1300000  1471000  1498500
# 2    AIREYS INLET  664000   625500   680000   715000   737500   869000
# 3    AIRPORT WEST  532000   575000   635000   742000   845000   845000
# 4       ALBANVALE  313000   328000   345000   439000   526500   546000
# ..            ...     ...      ...      ...      ...      ...      ...
# 686      YARRAGON  258000   297000   284000   300000   280000   390000
# 687        YARRAM  190000   202500   245000   230000   225000   218000
# 688    YARRAVILLE  696000   710000   810000   900500  1000000  1045000
# 689    YARRAWONGA  302500   297000   300500   320000   324500   345000
# 690           YEA  260000   255000   260000   305000   385000   390000
#
# 0       2019       2020       2021       2022       2023
# 0    1050000  1200000.0  1365000.0  1346000.0  1250000.0
# 1    1390000  1520000.0  1858000.0  1900000.0  1631000.0
# 2     985000  1132500.0  1775000.0  1725000.0  1675000.0
# 3     795000   812500.0   960000.0   911000.0   945000.0
# 4     512000   545000.0   610000.0   600000.0   595000.0
# ..       ...        ...        ...        ...        ...
# 686   410000   414000.0   582500.0   595000.0   645000.0
# 687   240000   260000.0   360000.0   470000.0   395000.0
# 688   971000  1030000.0  1185000.0  1210000.0  1100000.0
# 689   375000   456500.0   564500.0   670000.0   640000.0
# 690   435500   422500.0   570000.0   617500.0   550000.0
#
# [691 rows x 12 columns]

# %%
df_Melb_price.set_index('Locality')
mean_2013 = round(df_Melb_price[2013].astype("float").mean(), 2)
mean_2014=round(df_Melb_price[2014].astype("float").mean(), 2)
mean_2015=round(df_Melb_price[2015].astype("float").mean(), 2)
mean_2016=round(df_Melb_price[2016].astype("float").mean(), 2)
mean_2017=round(df_Melb_price[2017].astype("float").mean(), 2)
mean_2018=round(df_Melb_price[2018].astype("float").mean(), 2)
mean_2019=round(df_Melb_price[2019].astype("float").mean(), 2)
mean_2020=round(df_Melb_price[2020].astype("float").mean(), 2)
mean_2021=round(df_Melb_price[2021].astype("float").mean(), 2)
mean_2022=round(df_Melb_price[2022].astype("float").mean(), 2)
mean_2023=round(df_Melb_price[2023].astype("float").mean(), 2)

# %%
Melb_price_summary = pd.DataFrame({
    2013: [mean_2013],
    2014: [mean_2014],
    2015: [mean_2015],
    2016: [mean_2016],
    2017: [mean_2017],
    2018: [mean_2018],
    2019: [mean_2019],
    2020: [mean_2020],
    2021: [mean_2021],
    2022: [mean_2022],
    2023: [mean_2023],
    })
Melb_price_summary
Melb_housing_price = pd.DataFrame(Melb_price_summary).T
Melb_housing_price.reset_index(inplace=True)
Melb_housing_price.columns = ['Year', 'Price']
Melb_housing_price
# Out:
#     Year      Price
# 0   2013  470395.08
# 1   2014  504963.10
# 2   2015  562489.15
# 3   2016  615270.62
# 4   2017  695069.46
# 5   2018  707043.42
# 6   2019  695089.00
# 7   2020  749727.21
# 8   2021  892358.18
# 9   2022  939518.09
# 10  2023  912255.43

# %%
df_Melb_price_time_chart=Melb_housing_price.plot(x="Year", y="Price",kind="line")
#df_Melb_price_time_chart.set_xlabel("Year")            
#df_Melb_price_time_chart.set_ylabel("Melbourne Hosing Price")
plt.xticks ([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,2021,2022,2023])
#plt.xticks(list(map(int, Melb_housing_price.index.tolist())))
# Set a title for the chart
plt.title("Melbourne Hosing Price vs. Year")

plt.tight_layout()
plt.show()

# %%
Year=Melb_housing_price['Year']
Price=Melb_housing_price['Price']
slope, intercept, rvalue, pvalue, stderr = st.linregress(Year,Price)
p_fit = slope * Year+ intercept
line_price = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_price)
plt.scatter(Year,Price)
plt.plot(Year,p_fit,"-",color="red")
plt.annotate(line_price,(20,15),fontsize=15,color="red")
plt.xticks ([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,2021,2022,2023])
plt.ylabel('Melbourne Housing Price')
# Out:
# y = 47327.83x +-94803548.73
# Text(0, 0.5, 'Melbourne Housing Price')

# %%
excel_file_2 = Path("63020011B.xlsx")
df_salary = pd.read_excel(excel_file_2,header=[0,1], index_col=[0,1],skiprows=[2,3,4,5,6,7,8,9], sheet_name="Data1")

# %%
df_salary
# Out:
# Earnings; Males; Full Time; Adult; Ordinary time earnings ;  Victoria ; Earnings; Males; Full Time; Adult; Total earnings ;  Victoria ;  \
# $                                                                                                                                     $
# 2012-05-15 1379.9                                                                                                   1465.4
# 2012-11-15 1395.1                                                                                                   1483.2
# 2013-05-15 1416.9                                                                                                   1506.7
# 2013-11-15 1455.9                                                                                                   1536.7
# 2014-05-15 1462.6                                                                                                   1543.0
# 2014-11-15 1469.8                                                                                                   1550.8
# 2015-05-15 1478.8                                                                                                   1557.4
# 2015-11-15 1497.8                                                                                                   1575.0
# 2016-05-15 1529.7                                                                                                   1605.0
# 2016-11-15 1572.3                                                                                                   1651.9
# 2017-05-15 1584.9                                                                                                   1662.1
# 2017-11-15 1595.1                                                                                                   1671.9
# 2018-05-15 1611.6                                                                                                   1693.5
# 2018-11-15 1625.6                                                                                                   1701.4
# 2019-05-15 1664.2                                                                                                   1741.7
# 2019-11-15 1709.7                                                                                                   1791.0
# 2020-05-15 1765.0                                                                                                   1841.8
# 2020-11-15 1797.9                                                                                                   1867.4
# 2021-05-15 1835.3                                                                                                   1907.2
# 2021-11-15 1857.4                                                                                                   1935.9
# 2022-05-15 1861.3                                                                                                   1941.4
# 2022-11-15 1895.2                                                                                                   1984.8
# 2023-05-15 1928.9                                                                                                   2017.9
# 2023-11-15 1943.9                                                                                                   2024.3
#
# Earnings; Males; Full Time; Adult; Ordinary time earnings ;  Victoria ; Earnings; Males; Total earnings ;  Victoria ;  \
# $                                                                                                                   $
# 2012-05-15 1379.9                                                                                              1217.4
# 2012-11-15 1395.1                                                                                              1231.1
# 2013-05-15 1416.9                                                                                              1267.8
# 2013-11-15 1455.9                                                                                              1287.8
# 2014-05-15 1462.6                                                                                              1279.3
# 2014-11-15 1469.8                                                                                              1276.4
# 2015-05-15 1478.8                                                                                              1274.2
# 2015-11-15 1497.8                                                                                              1284.8
# 2016-05-15 1529.7                                                                                              1304.1
#            names=['Earnings; Males; Full Time; Adult; Ordinary time earnings ;  Victoria ;', '$'])

# %%
df_salary_clean=df_salary['Earnings; Persons; Total earnings ;  Victoria ;']

# %%
df_salary_clean.index
# Out:
# MultiIndex([('2012-05-15', 1379.9),
#             ('2012-11-15', 1395.1),
#             ('2013-05-15', 1416.9),
#             ('2013-11-15', 1455.9),
#             ('2014-05-15', 1462.6),
#             ('2014-11-15', 1469.8),
#             ('2015-05-15', 1478.8),
#             ('2015-11-15', 1497.8),
#             ('2016-05-15', 1529.7),
#             ('2016-11-15', 1572.3),
#             ('2017-05-15', 1584.9),
#             ('2017-11-15', 1595.1),
#             ('2018-05-15', 1611.6),
#             ('2018-11-15', 1625.6),
#             ('2019-05-15', 1664.2),
#             ('2019-11-15', 1709.7),
#             ('2020-05-15', 1765.0),
#             ('2020-11-15', 1797.9),
#             ('2021-05-15', 1835.3),
#             ('2021-11-15', 1857.4),
#             ('2022-05-15', 1861.3),
#             ('2022-11-15', 1895.2),
#             ('2023-05-15', 1928.9),
#             ('2023-11-15', 1943.9)],
#            )

# %%
df_s=df_salary_clean.reset_index()

# %%
df_s.index
# Out:
# RangeIndex(start=0, stop=24, step=1)

# %%
df_salary_r=df_s.rename(columns={'level_0': 'Year',  'level_1':'Male_income', '$':" Weekly Income" })

# %%
df_salary_r
# Out:
# $        Year  Male_income   Weekly Income
# 0  2012-05-15       1379.9          1003.2
# 1  2012-11-15       1395.1          1023.0
# 2  2013-05-15       1416.9          1046.3
# 3  2013-11-15       1455.9          1061.1
# 4  2014-05-15       1462.6          1058.6
# 5  2014-11-15       1469.8          1055.9
# 6  2015-05-15       1478.8          1057.9
# 7  2015-11-15       1497.8          1073.2
# 8  2016-05-15       1529.7          1092.6
# 9  2016-11-15       1572.3          1110.7
# 10 2017-05-15       1584.9          1129.4
# 11 2017-11-15       1595.1          1152.5
# 12 2018-05-15       1611.6          1171.8
# 13 2018-11-15       1625.6          1190.5
# 14 2019-05-15       1664.2          1209.3
# 15 2019-11-15       1709.7          1227.5
# 16 2020-05-15       1765.0          1242.7
# 17 2020-11-15       1797.9          1262.7
# 18 2021-05-15       1835.3          1269.9
# 19 2021-11-15       1857.4          1288.1
# 20 2022-05-15       1861.3          1299.9
# 21 2022-11-15       1895.2          1331.5
# 22 2023-05-15       1928.9          1373.2
# 23 2023-11-15       1943.9          1402.0

# %%
df_salary_r.columns
# Out:
# Index(['Year', 'Male_income', ' Weekly Income'], dtype='object', name='$')

# %%
df_salary_ready = df_salary_r.drop(columns=['Male_income'])

# %%
df_salary_ready
# Out:
# $        Year   Weekly Income
# 0  2012-05-15          1003.2
# 1  2012-11-15          1023.0
# 2  2013-05-15          1046.3
# 3  2013-11-15          1061.1
# 4  2014-05-15          1058.6
# 5  2014-11-15          1055.9
# 6  2015-05-15          1057.9
# 7  2015-11-15          1073.2
# 8  2016-05-15          1092.6
# 9  2016-11-15          1110.7
# 10 2017-05-15          1129.4
# 11 2017-11-15          1152.5
# 12 2018-05-15          1171.8
# 13 2018-11-15          1190.5
# 14 2019-05-15          1209.3
# 15 2019-11-15          1227.5
# 16 2020-05-15          1242.7
# 17 2020-11-15          1262.7
# 18 2021-05-15          1269.9
# 19 2021-11-15          1288.1
# 20 2022-05-15          1299.9
# 21 2022-11-15          1331.5
# 22 2023-05-15          1373.2
# 23 2023-11-15          1402.0

# %%
df_salary_ready.dtypes
# Out:
# $
# Year              datetime64[ns]
#  Weekly Income           float64
# dtype: object

# %%
fitlter_salary=df_salary_ready[df_salary_ready['Year'].dt.month==11]

# %%
fitlter_salary['Annual_Salary']= fitlter_salary[' Weekly Income'] * 52
# Out:
# C:\Users\Ariaaa\AppData\Local\Temp\ipykernel_2760\3347563268.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitlter_salary['Annual_Salary']= fitlter_salary[' Weekly Income'] * 52

# %%
fitlter_salary
# Out:
# $        Year   Weekly Income  Annual_Salary
# 1  2012-11-15          1023.0        53196.0
# 3  2013-11-15          1061.1        55177.2
# 5  2014-11-15          1055.9        54906.8
# 7  2015-11-15          1073.2        55806.4
# 9  2016-11-15          1110.7        57756.4
# 11 2017-11-15          1152.5        59930.0
# 13 2018-11-15          1190.5        61906.0
# 15 2019-11-15          1227.5        63830.0
# 17 2020-11-15          1262.7        65660.4
# 19 2021-11-15          1288.1        66981.2
# 21 2022-11-15          1331.5        69238.0
# 23 2023-11-15          1402.0        72904.0

# %%
fitlter_salary['Year'] = fitlter_salary['Year'].dt.year
# Out:
# C:\Users\Ariaaa\AppData\Local\Temp\ipykernel_2760\3393866221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fitlter_salary['Year'] = fitlter_salary['Year'].dt.year

# %%
fitlter_salary
# Out:
# $   Year   Weekly Income  Annual_Salary
# 1   2012          1023.0        53196.0
# 3   2013          1061.1        55177.2
# 5   2014          1055.9        54906.8
# 7   2015          1073.2        55806.4
# 9   2016          1110.7        57756.4
# 11  2017          1152.5        59930.0
# 13  2018          1190.5        61906.0
# 15  2019          1227.5        63830.0
# 17  2020          1262.7        65660.4
# 19  2021          1288.1        66981.2
# 21  2022          1331.5        69238.0
# 23  2023          1402.0        72904.0

# %%
annual_salary_df=fitlter_salary.drop(columns=[' Weekly Income'])

# %%
annual_salary=annual_salary_df.drop(1)

# %%
annual_salary.set_index('Year')
# Out:
# $     Annual_Salary
# Year
# 2013        55177.2
# 2014        54906.8
# 2015        55806.4
# 2016        57756.4
# 2017        59930.0
# 2018        61906.0
# 2019        63830.0
# 2020        65660.4
# 2021        66981.2
# 2022        69238.0
# 2023        72904.0

# %%
Year=annual_salary['Year']
Annual_Salary=annual_salary['Annual_Salary']
slope, intercept, rvalue, pvalue, stderr = st.linregress(Year,Annual_Salary)
p_fit = slope * Year+ intercept
line_salary = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_salary)
plt.scatter(Year,Annual_Salary)
plt.plot(Year,p_fit,"-",color="red")
plt.annotate(line_salary,(20,15),fontsize=15,color="red")
plt.xticks ([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,2021,2022,2023])
plt.ylabel('Annual_Salary')
# Out:
# y = 1810.83x +-3592062.52
# Text(0, 0.5, 'Annual_Salary')

# %%
annual_salary.columns
# Out:
# Index(['Year', 'Annual_Salary'], dtype='object', name='$')

# %%
#linear regession

# %%
Salary_price=pd.merge(annual_salary,Melb_housing_price, on=['Year'],how='inner',suffixes=['_and'])

# %%
Salary_price
# Out:
#     Year  Annual_Salary      Price
# 0   2013        55177.2  470395.08
# 1   2014        54906.8  504963.10
# 2   2015        55806.4  562489.15
# 3   2016        57756.4  615270.62
# 4   2017        59930.0  695069.46
# 5   2018        61906.0  707043.42
# 6   2019        63830.0  695089.00
# 7   2020        65660.4  749727.21
# 8   2021        66981.2  892358.18
# 9   2022        69238.0  939518.09
# 10  2023        72904.0  912255.43

# %%
salary_vs_price_chart= Salary_price.plot(x="Annual_Salary", y="Price", kind="scatter")
salary_vs_price_chart.set_xlabel("Annual_Salary")
salary_vs_price_chart.set_ylabel("Melbourne Housing Price")

# Set a title for the chart
plt.title("Annual_Salary vs. Melbourne House Price")

plt.tight_layout()
plt.show()

# %%
Annual_Salary=Salary_price['Annual_Salary']
Melbourne_Housing_Price=Salary_price['Price']
slope, intercept, rvalue, pvalue, stderr = st.linregress(Annual_Salary, Melbourne_Housing_Price)
p_fit = slope * Annual_Salary + intercept
line_tem = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_tem)
plt.scatter(Annual_Salary,Melbourne_Housing_Price)
plt.plot(Annual_Salary,p_fit,"-",color="red")
plt.annotate(line_tem,(20,15),fontsize=15,color="red")
#plt.xticks(TemperatuAnnualMelbourne Housing Pricey')
plt.ylabel('Melbourne Housing Price)')
plt.show()
# Out:
# y = 25.25x +-866264.94

# %%
# Calculate the Pearson correlation coefficient
correlation, p_value = st.pearsonr(Salary_price['Price'], Salary_price['Annual_Salary'])
print(f"Pearson correlation coefficient: {correlation}")
print(f"P-value: {p_value}")
print(f"Pearson correlation coefficient: {correlation}")
print(f"P-value: {p_value}")
# Out:
# Pearson correlation coefficient: 0.9549287539298656
# P-value: 4.805042566975307e-06
# Pearson correlation coefficient: 0.9549287539298656
# P-value: 4.805042566975307e-06

# %%
# Plotting both Average Interest Rate and Housing Price
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot Average Interest Rate
ax1.set_xlabel('Year')
ax1.set_ylabel('Salary', color='tab:blue')
ax1.plot(Salary_price['Year'], Salary_price['Annual_Salary'], color='tab:blue', label='Annual Salary')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis to plot Housing Price
ax2 = ax1.twinx()
ax2.set_ylabel('Housing Price ($)', color='tab:red')
ax2.plot(Salary_price['Year'], Salary_price['Price'], color='tab:red', label='Housing Price')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Adding a title
plt.title('Annual Salary and Housing Prices Over Time')

# Show plot with legends
fig.tight_layout()
fig.legend(loc='upper left', bbox_to_anchor=(0.1,0.9))

plt.show()

# %%
Salary_price["Price to income "]=Salary_price["Price"] / Salary_price["Annual_Salary"]

# %%
Salary_price
# Out:
#     Year  Annual_Salary      Price  Price to income
# 0   2013        55177.2  470395.08          8.525171
# 1   2014        54906.8  504963.10          9.196732
# 2   2015        55806.4  562489.15         10.079295
# 3   2016        57756.4  615270.62         10.652856
# 4   2017        59930.0  695069.46         11.598022
# 5   2018        61906.0  707043.42         11.421242
# 6   2019        63830.0  695089.00         10.889691
# 7   2020        65660.4  749727.21         11.418255
# 8   2021        66981.2  892358.18         13.322517
# 9   2022        69238.0  939518.09         13.569400
# 10  2023        72904.0  912255.43         12.513105
